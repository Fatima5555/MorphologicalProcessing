# %%
import cv2
vidcap = cv2.VideoCapture('C:/Users/Dell/Videos/FYP/video2.mp4')
success,image = vidcap.read()
count = 0
while(success):
  cv2.imwrite("frame%d.jpg" % count, image)     # save frame as JPEG file      
  success,image = vidcap.read()
  #print('Read a new frame: ', image)
  count += 1

# %%
count
# Out:
# 3003

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

#edge detection
def sobelOperator(img):
    container = np.copy(img)
    size = container.shape
    for i in range(1, size[0] - 1):
        for j in range(1, size[1] - 1):
            gx = (img[i - 1][j - 1] + 2*img[i][j - 1] + img[i + 1][j - 1]) - (img[i - 1][j + 1] + 2*img[i][j + 1] + img[i + 1][j + 1])
            gy = (img[i - 1][j - 1] + 2*img[i - 1][j] + img[i - 1][j + 1]) - (img[i + 1][j - 1] + 2*img[i + 1][j] + img[i + 1][j + 1])
            container[i][j] = min(255, np.sqrt(gx**2 + gy**2))
    return container
    pass
count=10
for i in range(count):
    img = cv2.cvtColor(cv2.imread("frame%d.jpg" % i), cv2.COLOR_BGR2GRAY)
    img = sobelOperator(img)
    img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
    plt.imshow(img)
    plt.show()

# %%
#erosion
count=10
for i in range(count):
    kernel = np.ones((5,5),np.uint8)
    erosion = cv2.erode(img,kernel,iterations = 1)
    plt.imshow(erosion)
    plt.show()

# %%
#dilation
count=10
for i in range(count):
    dilation = cv2.dilate(img,kernel,iterations = 1)
    plt.imshow(dilation)
    plt.show()
